# %% [markdown]
# <a href="https://colab.research.google.com/github/congltk1234/Fashion_Items_Classification/blob/main/FashionMNIST/Preprocess_image_predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
INPUT_IMAGE_URL = "https://i.pinimg.com/236x/04/3a/e8/043ae802b230fbff5f86c372e19dab67.jpg" #@param {type:"string"}
# Tải về
# !wget -q -O input.jpg $INPUT_IMAGE_URL
from PIL import Image
# Đọc ảnh bằng thư viện Pillow
image = Image.open('input.jpg')
import numpy as np
print('Img size:',np.array(image).shape)
print('Type:',image.mode)
image
# Out:
# Img size: (354, 236, 3)
# Type: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x354>

# %%
# @title Mở rộng ảnh với nền trắng, chuyển về dạng ảnh Vuông w=h
def expand2square(pil_img, background_color):
    width, height = pil_img.size
    if width == height:
        return pil_img
    elif width > height:
        result = Image.new("RGB", (width, width), background_color)
        result.paste(pil_img, (0, (width - height) // 2))
        result.save("expanded_image.jpg")

        return result
    else:
        result = Image.new("RGB", (height, height), background_color)
        result.paste(pil_img, ((height - width) // 2, 0))
        result.save("expanded_image.jpg")
        return result

image = expand2square(image, 'white')
print('Img size:',np.array(image).shape)
print('Type:',image.mode)
image
# Out:
# Img size: (354, 354, 3)
# Type: RGB
# <PIL.Image.Image image mode=RGB size=354x354>

# %%
# @title Ảnh màu -> Ảnh xám
from PIL import Image
image = image.convert('L')
print('Img size:',np.array(image).shape)
print('Type:',image.mode)
image
# Out:
# Img size: (354, 354)
# Type: L
# <PIL.Image.Image image mode=L size=354x354>

# %%
image.thumbnail((28,28))
print('Img size:',np.array(image).shape)
print('Type:',image.mode)
image
# Out:
# Img size: (28, 28)
# Type: L
# <PIL.Image.Image image mode=L size=28x28>
